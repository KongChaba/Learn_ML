# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#เรียกข้อมูลไฟล์ csv จากลิงค์ ไป ตัวแปร dataset
dataset = pd.read_csv("https://raw.githubusercontent.com/kongruksiamza/MachineLearning/master/Linear%20Regression/Weather.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 #เรียกข้อมูลไฟล์ csv จากลิงค์ ไป ตัวแปร dataset
# ----> 2 dataset = pd.read_csv("https://raw.githubusercontent.com/kongruksiamza/MachineLearning/master/Linear%20Regression/Weather.csv")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
print(dataset.shape)
# Out:
# (119040, 31)

# %%
#สร้างกราฟ
#style="o" สร้างกราฟแบบจุด
dataset.plot(x='MinTemp', y='MaxTemp',style="o")
plt.title('Min & Max Temp') #title ของ กราฟ
plt.xlabel("Mintemp") #ชื่อของแกน x
plt.ylabel("Maxtemp") #ชื่อของแกน y
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#train & test set
x = dataset["MinTemp"].values.reshape(-1,1)
y = dataset["MaxTemp"].values.reshape(-1,1)

# %%
# 80% - 20%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#training
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#test
y_pred = model.predict(x_test)

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test,y_pred,color="red",linewidth=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#compare true data & predict data
df = pd.DataFrame({'Actually':y_test.flatten(), 'Predicted':y_pred.flatten()})

print(df.head())
print(df.shape)
# Out:
#     Actually  Predicted
# 0  28.888889  33.670351
# 1  31.111111  30.091251
# 2  27.222222  26.512151
# 3  28.888889  31.113851
# 4  23.333333  15.774852
# (23808, 2)

# %%
df1 = df.head(20)
df1.plot(kind="bar",figsize=(16,10))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
